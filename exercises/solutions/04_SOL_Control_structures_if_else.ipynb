# %% [markdown]
# <!-- bootcamp-header: generated by tools/build_headers.py, edit the README timetable instead -->
# # Solutions: Control structures: if and else
#
# Worked solutions to the exercises in [`04_EX_Control_structures_if_else.ipynb`](https://github.com/mikekestemont/dtaantwerp26-27.github.io/blob/DTA_Bootcamp_2026_students/exercises/questions/04_EX_Control_structures_if_else.ipynb), which go with the session [`04_W1_Wed_Control_structures_if_else.ipynb`](https://github.com/mikekestemont/dtaantwerp26-27.github.io/blob/DTA_Bootcamp_2026_students/notebooks/04_W1_Wed_Control_structures_if_else.ipynb).
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mikekestemont/dtaantwerp26-27.github.io/blob/DTA_Bootcamp_2026_students/exercises/solutions/04_SOL_Control_structures_if_else.ipynb)

# %% [markdown]
# Every exercise is followed by one possible solution (sometimes two). Other correct solutions exist: what matters is that yours works and that you understand why.

# %% [markdown]
# ## Core exercises

# %% [markdown]
# ### 1. Long words (basic)
#
# Print `a long word` if the word has ten or more letters. Test your code with a shorter word too.

# %%
word = 'incomprehensible'

if len(word) >= 10:
    print('a long word')
# Out:
# a long word

# %% [markdown]
# ### 2. Is the letter there? (basic)
#
# Check whether the letter occurs in the sentence. If it does, print `found it!`; if it does not, print `not in the sentence`.

# %%
letter = 'a'
sentence = 'does this sentence contain the letter?'

if letter in sentence:
    print('found it!')
else:
    print('not in the sentence')
# Out:
# found it!

# %% [markdown]
# ### 3. Same or different (basic)
#
# Print `they are the same` if `x` equals `y`, and `they are not the same` otherwise. Check the result for both cells: why is the first pair equal and the second not?

# %%
x = 3
y = 6 * 2 / 3 - 1

if x == y:
    print('they are the same')
else:
    print('they are not the same')

# 6 * 2 / 3 - 1 is 3.0, and 3 == 3.0 is True: Python compares the values, not the types.
# In the second pair y is 4.0, so the two are not equal.
# Out:
# they are the same

# %% [markdown]
# ### 4. On the reading list (basic)
#
# Check whether the title is on the reading list. If it is, print a message saying so; if not, print that the book still has to be read.

# %%
reading_list = ['Emma', 'Dracula', 'Persuasion', 'Middlemarch', 'Kidnapped']
title = 'Dracula'

if title in reading_list:
    print(f'{title} is on the reading list.')
else:
    print(f'{title} still has to be read.')
# Out:
# Dracula is on the reading list.

# %% [markdown]
# ### 5. Even or odd (basic)
#
# Print whether the number is even or odd. Hint: the `%` operator.

# %%
number = 17

if number % 2 == 0:
    print('even')
else:
    print('odd')
# Out:
# odd

# %% [markdown]
# ### 6. Vowel or consonant (standard)
#
# Print whether the letter is a vowel or a consonant. Make sure that a capital letter is classified correctly too.

# %%
vowels = 'aeiou'
letter = 'E'

if letter.lower() in vowels:
    print('vowel')
else:
    print('consonant')
# Out:
# vowel

# %% [markdown]
# ### 7. Ratings (standard)
#
# A review site turns scores into ratings. Print:
#
# - `A` if the score is higher than 90;
# - `B` if it is higher than 60;
# - `C` if it is higher than 50;
# - `F` in all other cases.
#
# Use `if`, `elif` and `else`, and make sure the tests do not overlap.

# %%
score = 75

if score > 90:
    print('A')
elif score > 60:
    print('B')
elif score > 50:
    print('C')
else:
    print('F')
# Out:
# B

# %% [markdown]
# The order of the tests matters: `score > 60` would also be true for 95, but a score of 95 never reaches that test because the first one already caught it.

# %% [markdown]
# ### 8. Guilty? (standard)
#
# A suspect is only guilty if all three conditions are `True`. Print `guilty` in that case, and `innocent until proven otherwise` in all others. Try changing the variables.

# %%
means = True
motive = False
opportunity = True

if means and motive and opportunity:
    print('guilty')
else:
    print('innocent until proven otherwise')
# Out:
# innocent until proven otherwise

# %% [markdown]
# ### 9. Predict the output (standard)
#
# Read the code and decide which statements will be printed, *before* you run the cell. Then run it and check.

# %%
x = 9

if x <= 10 and x < 5:    # False: 9 is not smaller than 5
    print('statement 1')
if x >= 8:               # True, so statement 2 is printed ...
    print('statement 2')
elif x == 9:             # ... and this test is never looked at, even though it would be True
    print('statement 3')
else:
    print('statement 4')
# Out:
# statement 2

# %% [markdown]
# ## Extra exercises

# %% [markdown]
# ### 10. A modest holiday (standard)
#
# A couple wants to go on holiday, but they cannot go over their budget of 1000 euros, and they are afraid of flying. Write code that checks whether the cost is within the budget *and* the way of travelling is not by plane. If both conditions are met, print `Bon voyage!`; otherwise print `Choose another destination`.

# %%
budget = 1000
way_of_travel = 'plane'
cost = 800

if cost <= budget and way_of_travel != 'plane':
    print('Bon voyage!')
else:
    print('Choose another destination')
# Out:
# Choose another destination

# %% [markdown]
# ### 11. Seasons (standard)
#
# Ask the user for a season with `input()` and print the date on which that season starts:
#
# - spring starts on 20 March;
# - summer starts on 21 June;
# - autumn starts on 23 September;
# - winter starts on 21 December.
#
# Accept `fall` as well as `autumn` (hint: `or`), and make the code work whatever capitalisation the user types (hint: `.lower()`). Print a message for anything that is not a season.

# %%
season = input('Which season? ').lower()

if season == 'spring':
    print('Spring starts on 20 March.')
elif season == 'summer':
    print('Summer starts on 21 June.')
elif season == 'autumn' or season == 'fall':
    print('Autumn starts on 23 September.')
elif season == 'winter':
    print('Winter starts on 21 December.')
else:
    print('That is not a season.')

# %% [markdown]
# ### 12. Literary periods (standard)
#
# Print the period a novel belongs to, based on its year of publication:
#
# - before 1660: early modern;
# - from 1660 to 1789: Restoration and eighteenth century;
# - from 1790 to 1836: Romantic;
# - from 1837 to 1900: Victorian;
# - after 1900: modern.
#
# Make sure that every year ends up in exactly one period. Test with a few different years.

# %%
year = 1851

if year < 1660:
    print('early modern')
elif year <= 1789:
    print('Restoration and eighteenth century')
elif year <= 1836:
    print('Romantic')
elif year <= 1900:
    print('Victorian')
else:
    print('modern')
# Out:
# Victorian

# %% [markdown]
# Because each `elif` only sees the years the previous tests did not catch, the lower bound of every period is implied: `year <= 1789` is only tested for years of 1660 and later.

# %% [markdown]
# ### 13. Discounts (standard)
#
# Ask the user for their age and print whether they are eligible for a student discount (under 26), a senior discount (over 65), or no discount at all. Hint: `input()` returns a string, so cast it with `int()` before comparing.

# %%
age = int(input('How old are you? '))

if age < 26:
    print('student discount')
elif age > 65:
    print('senior discount')
else:
    print('no discount')

# %% [markdown]
# ### 14. Divisible (harder)
#
# Write code that prints whether the number is:
#
# - divisible by both two and three;
# - divisible by two only;
# - divisible by three only;
# - divisible by neither.
#
# Exactly one message should be printed. Think about the order of the tests.

# %%
number = 12

if number % 2 == 0 and number % 3 == 0:
    print('divisible by two and three')
elif number % 2 == 0:
    print('divisible by two only')
elif number % 3 == 0:
    print('divisible by three only')
else:
    print('divisible by neither')
# Out:
# divisible by two and three

# %% [markdown]
# The combined test has to come first: if `number % 2 == 0` were tested first, 12 would be caught there and never reach the combined test.

# %% [markdown]
# ### 15. Only the first (harder)
#
# The cell prints two lines. Change the *structure* of the code (not the numbers) so that only the first statement is printed.

# %%
number = 6

if number < 9:
    print('This should be printed')
elif number > 18:
    print('This should not be printed')
else:
    print('This should not be printed either')

# The two tests were independent if statements, so the second one ran (and its else fired).
# With elif, the second test belongs to the first, and is skipped once the first succeeds.
# Out:
# This should be printed

# %% [markdown]
# ### 16. The shortest word (harder)
#
# Print the shortest of the three words, using only `if`, `elif`, `else` and comparisons (no `min()`). What does your code do when two words are equally long?

# %%
word_1 = 'serendipity'
word_2 = 'ink'
word_3 = 'quill'

if len(word_1) <= len(word_2) and len(word_1) <= len(word_3):
    print(word_1)
elif len(word_2) <= len(word_3):
    print(word_2)
else:
    print(word_3)

# With <=, the first of two equally short words wins; with < it would be the last one.
# Out:
# ink

# %% [markdown]
# ## Class exercises from the session notebook
#
# Solutions to the exercises that are solved together during the session, for reference afterwards.

# %% [markdown]
# **Numerical tests.** Three `if` statements: a number greater than 3; two numbers that are the same; two numbers that are different.

# %%
x = 5

if x > 3:
    print(x)
# Out:
# 5

# %%
x = 4
y = 5

if x == y:
    print('same same')

# %%
x = 4
y = 5

if x != y:
    print('not the same')
# Out:
# not the same

# %% [markdown]
# **Amber.** A nested `if` inside the `else` block for an amber traffic light.

# %%
traffic_light = 'amber'

if traffic_light == 'red':
    print('stop')
else:
    if traffic_light == 'amber':
        print('wait')
    else:
        print('go')

# The elif version in the session says the same thing with one level of indentation less.
# Out:
# wait

# %% [markdown]
# **A power cut.** What happens when the light is off? The `else` block runs, so the car goes: nothing in the tests catches an unknown value. The exercise on unknown answers below fixes that.

# %% [markdown]
# **Steam, water, ice.** Without overlapping tests: one test with `>`, one with `<`, and `else` for everything in between.

# %%
temperature = 100

if temperature > 100:
    print('steam')
elif temperature < 0:
    print('ice')
else:
    print('water')

# 100 itself is not above 100, so it prints water; try 101 and -1.
# Out:
# water

# %% [markdown]
# **Unknown answers.** Green means go; anything that is not red, amber or green gets a warning.

# %%
traffic_light = input('What colour is the traffic light? ')

if traffic_light == 'red':
    print('stop')
elif traffic_light == 'amber':
    print('wait')
elif traffic_light == 'green':
    print('go')
else:
    print('drive slowly and look both ways')

# %% [markdown]
# **Going home.** We go home if the distance home is within the fuel range, *or* if the petrol station is closer than home.

# %%
distance_home = int(input('Distance home: '))
fuel_range = int(input('Fuel range: '))
distance_to_station = 100

if distance_home < fuel_range or distance_to_station < distance_home:
    print("We're going home")
else:
    print('Oh no')
