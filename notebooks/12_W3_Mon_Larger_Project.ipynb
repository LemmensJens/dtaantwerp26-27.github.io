# %% [markdown]
# <!-- bootcamp-header: generated by tools/build_headers.py, edit the README timetable instead -->
# # Project work
#
# **Session:** Monday 5 October 2026, 14:00-16:00, room S.SJ.117
# **Tutors:** Jens Lemmens / TBD
# **Solution:** [`12_SOL_Larger_Project.ipynb`](https://github.com/LemmensJens/dtaantwerp26-27.github.io/blob/DTA_Bootcamp_2026_students/exercises/solutions/12_SOL_Larger_Project.ipynb) (look at it after the session, not before)
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LemmensJens/dtaantwerp26-27.github.io/blob/DTA_Bootcamp_2026_students/notebooks/12_W3_Mon_Larger_Project.ipynb)

# %% [markdown]
# ## A larger project
#
# The exercises so far each practised one thing. Real programs combine many things, and the difficulty is rarely in any single line: it is in deciding what the pieces are, writing them one by one, testing each, and putting them together. This session is one such program, built from what you learned in the past two weeks, and nothing else: `input()` and the keep-asking loop, string methods and `string.punctuation`, dictionaries, functions with `return`, and `while` loops with `break`.
#
# You work in pairs or alone; the tutors walk around. There is no exercise notebook: this notebook is the exercise. A worked solution is linked in the header; open it *after* the session, or when you are really stuck on one piece, not before you have tried.
#
# After this session you can:
#
# - turn a description in plain language into a list of concrete requirements;
# - split a program into functions that each do one thing, and test each function on its own;
# - assemble the functions into a working program with a simple menu.

# %% [markdown]
# ## The project: an authentication system
#
# **Assignment.** Write a small, naive authentication system, of the kind a website uses to let people register and log in. Before you read the detailed requirements below, think for a minute about what such a system must be able to do, and sketch it on paper: what does it ask the user, what does it store, what can go wrong, and what should happen then?
#
# The system needs two parts.
#
# **(A) Registration.** Ask the user, with `input()`, for an e-mail address (which serves as the user name) and a password, and store the pair in a suitable data structure, the "database". Only accept the registration if both are valid:
#
# - A **valid e-mail address**, for our purposes: contains exactly one `@`; ends in `.com`, `.org` or `.be`; contains no punctuation other than `-`, `@` and `.`.
# - A **valid password**: at least 8 characters long; contains upper case *and* lower case letters; contains at least two digits; contains no punctuation.
#
# Keep asking until the user gets it right. Print exactly these messages under the corresponding conditions:
#
# - `You entered an invalid email address. Try again.`
# - `That user name has already been taken. Try again.`
# - `Your password is not valid. Try again.` (feel free to say what was wrong with it)
# - `Your account has been successfully created!`
#
# **(B) Login.** Ask the user for an e-mail address and a password, and grant access if the address is in the database and the password matches. A wrong password costs an attempt; after three wrong passwords, stop and "send a warning e-mail" to the last address used (we cannot really send e-mail: print a message that says what the e-mail would contain). Messages:
#
# - `This email address does not exist in our database. Try again.`
# - `Your email address exists, but your password is incorrect. Try again. (N attempts left)`
# - `You have successfully logged in!`
# - `You have exhausted your 3 login attempts. A warning message has been emailed to the last email address used.`

# %% [markdown]
# ## How to approach it
#
# Do not start by typing. Start by reading the assignment twice and turning it into a **checklist of requirements**: every rule about e-mail addresses, every rule about passwords, every message and when it is printed. Then decide on your **data structure** for the database (which type maps a user name to a password?). Only then think about **functions**: which small tasks come back more than once, and what does each one take and return?
#
# A decomposition that works well is given below as a series of steps. Follow it, or design your own; what matters is that every function is tested before you use it in the next step.
#
# ### Step 1: validating an e-mail address
#
# Write `is_valid_email(address)`, which returns `True` or `False`, and nothing else (no printing: the caller decides what to say). Test it with addresses that should pass and addresses that should fail, one per rule.
#
# Hints: `.count()` for the `@`; `.endswith()` accepts a *tuple* of endings, `address.endswith(('.com', '.org', '.be'))`, and returns `True` if any of them matches; `string.punctuation` lists every punctuation character, so a loop over the characters can check that each one is either not punctuation or one of the three allowed ones.

# %%
import string

# your code here

# %%
# tests: every line should print the expected value
print(is_valid_email('ada.lovelace@example.com'), 'expected True')
print(is_valid_email('ada-lovelace@example.be'), 'expected True')
print(is_valid_email('ada@@example.com'), 'expected False')
print(is_valid_email('ada@example.nl'), 'expected False')
print(is_valid_email('ada_lovelace@example.com'), 'expected False')

# %% [markdown]
# ### Step 2: validating a password
#
# Write `is_valid_password(password)` the same way. Count what you need to count in one loop over the characters (`.isupper()`, `.islower()`, `.isdigit()`), and return `False` the moment you meet punctuation.

# %%
# your code here

# %%
print(is_valid_password('Wonderland1865'), 'expected True')
print(is_valid_password('wonderland1865'), 'expected False, no upper case')
print(is_valid_password('Wonder1'), 'expected False, too short')
print(is_valid_password('Wonderland!1865'), 'expected False, punctuation')
print(is_valid_password('Wonderland1'), 'expected False, one digit')

# %% [markdown]
# ### Step 3: registration
#
# Write `register(users)`, where `users` is the database dictionary. It asks for an address until it gets a valid one that is not yet taken, then for a password until it gets a valid one, adds the pair to the dictionary and prints the success message. The "ask until valid" loop is the pattern from the session on files: `while True:`, ask, `break` if acceptable, otherwise print the message and go round again.
#
# Notice that the function *changes* the dictionary it receives: that is the list trap from the session on functions, used on purpose.

# %%
# your code here

# %%
users = {}
register(users)
print(users)

# %% [markdown]
# ### Step 4: login
#
# Write `login(users)`. Keep a counter of attempts left, starting at 3. An address that is not in the database does not cost an attempt (the spec only counts wrong passwords); a wrong password does. Return `True` when the login succeeds and `False` when the attempts run out, after "sending" the warning: a separate little function `send_warning(address)` that prints what the e-mail would say keeps `login()` readable.

# %%
# your code here

# %%
login(users)

# %% [markdown]
# ### Step 5: a menu
#
# Put it together: a `while True:` loop that asks whether the user wants to *register*, *log in* or *quit*, calls the right function, and stops on *quit*. Test the whole thing: register, log in with the right password, log in with the wrong one three times.

# %%
# your code here

# %% [markdown]
# ## If you have time left
#
# - **Persistence.** The database is gone when the kernel restarts. Write `save_users(users, path)` and `load_users(path)` that write and read the dictionary as a text file with one `address<TAB>password` line per user (the session on files showed how), and call them at the start and the end of the menu.
# - **Better feedback.** Let `is_valid_password()` return a *list of the rules that failed* instead of `False`, so that the registration can tell the user exactly what to fix. What does an empty list mean, and how does `if` treat it?
# - **Real e-mail rules.** Look up what a real e-mail address may contain and improve `is_valid_email()`; a regular expression will serve you well here.
#
# (Whatever you do: never store real passwords like this. Real systems store a scrambled version, a *hash*, never the password itself. This project is about program structure, not about security.)
